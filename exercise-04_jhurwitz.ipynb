# %% [markdown]
# # Exercise 04 - Due Friday, October 21 at 12pm
#
# *Objectives*: Gain experience loading a CSV dataset into a database model you define yourself and using SQL to explore its contents. Explore the data by writing and executing a number of SQL queries using common syntax and functions and describing your findings.
#
# *Grading criteria*: The tasks should all be completed, and questions should all be answered with SQL queries in the space provided, unless a text answer is requested. Results should be correct, according to the embedded tests. The notebook itself should be completely reproducible; from start to finish, another person should be able to use the same code to obtain the same results as yours.  Note that you will receive no more than partial credit if you do not add text/markdown cells explaining your thinking at each major step in each problem.
#
# *Deadline*: Friday, October 21, 12pm. Submit your notebook to Blackboard and push it to your GitHub repository.
#
# ## Setup - obtain data and create database
#
# The US City Open Data Census has data on [restaurant inspections from all over the country](http://us-city.census.okfn.org/dataset/food-safety).  Let's take a look at data from Albuquerque.  *Note*: metadata and other details for this dataset are available at http://data.cabq.gov/business/foodinspections/.
#
# Fyi, to save you a step, I've converted this file into a clean CSV file by using the `dos2unix` command to change its line endings and to switch it to use commas instead of tabs using `csvformat -t inputfile.csv > outputfile.csv`.
#
# First we download the dataset:

# %%
# !wget https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Out:
# --2016-10-24 01:13:08--  https://raw.githubusercontent.com/gwsb-istm-6212-fall-2016/syllabus-and-schedule/master/exercises/abq-food-inspections-fy2010.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5025226 (4.8M) [text/plain]
# Saving to: ‘abq-food-inspections-fy2010.csv’
#
# abq-food-inspection 100%[=====================>]   4.79M  --.-KB/s   in 0.09s
#
# 2016-10-24 01:13:08 (51.4 MB/s) - ‘abq-food-inspections-fy2010.csv’ saved [5025226/5025226]

# %% [markdown]
# ## Problem 1 - examine the data (35 points)
#
# Use `csvstat` and other tools as you see fit and observe its contents.  Review the metadata definitions linked to above.  Describe what you see:  What do all the columns mean?  Are there null values?  Which columns interest you the most?  Which columns present some complications or questions you would like to ask?

# %% [markdown]
# Insert a combination of code and text/markdown cells here to review the data and describe what you find.

# %% [markdown]
# Step 1: Rename csv file into something shorter so it is easier to reference

# %%
# !mv abq-food-inspections-fy2010.csv abq.csv

# %% [markdown]
# Step 2: Examine columns

# %%
# !csvcut -n abq.csv
# Out:
#   1: FACILITY_NAME
#   2: FACILITY_KEY
#   3: SITE_ADDRESS
#   4: CITY
#   5: STATE
#   6: ZIP
#   7: OWNER_KEY
#   8: OWNER_NAME
#   9: NATURE_OF_BUSINESS
#  10: STREET_NUMBER
#  11: STREET_NAME
#  12: STREET_TYPE
#  13: POST_DIRECTIONAL
#  14: PHONE
#  15: PROGRAM_CATEGORY
#  16: PROGRAM_CATEGORY_DESCRIPTION
#  17: INSPECTION_DATE
#  18: INSPECTION_TYPE
#  19: INSPECTION_DESC
#  20: SERIAL_NUM
#  21: ACTION_CODE
#  22: ACTION_DESC
#  23: RESULT_CODE
#  24: RESULT_DESC
#  25: VIOLATION_CODE
#  26: VIOLATION_DESC
#  27: INSPECTION_MEMO

# %% [markdown]
# The columns appear to contain a variety of fields pertaining to information about the restaurant location, the owner, the nature of the inspection, and the outcome of the inspection. The columns that interest me the most would be violation_code and violation_desc. As someone who eats out regularly, I would want to make sure to avoid these restaurants should I ever visit Albuquerque!

# %% [markdown]
# Step 3: Examine sample of data (broken into 3 steps due to width of table)

# %%
# !csvcut -c1-9 abq.csv | head -10 | csvlook
# Out:
# |--------------------------+--------------+-------------------------------+-------------+-------+-------+-----------+-------------------------+---------------------|
# |  FACILITY_NAME           | FACILITY_KEY | SITE_ADDRESS                  | CITY        | STATE | ZIP   | OWNER_KEY | OWNER_NAME              | NATURE_OF_BUSINESS  |
# |--------------------------+--------------+-------------------------------+-------------+-------+-------+-----------+-------------------------+---------------------|
# |  00BSAY IT WITH CAKE     | 50534        | 10200 GOLF COURSE RD NW STE B | ALBUQUERQUE | NM    | 87114 | 47341     | OOBSAY IT WITH CAKE     | CAKE DECORATING     |
# |  00BSAY IT WITH CAKE     | 50534        | 10200 GOLF COURSE RD NW STE B | ALBUQUERQUE | NM    | 87114 | 47341     | OOBSAY IT WITH CAKE     | CAKE DECORATING     |
# |  00BSAY IT WITH CAKE     | 50534        | 10200 GOLF COURSE RD NW STE B | ALBUQUERQUE | NM    | 87114 | 47341     | OOBSAY IT WITH CAKE     | CAKE DECORATING     |
# |  00BSAY IT WITH CAKE     | 50534        | 10200 GOLF COURSE RD NW STE B | ALBUQUERQUE | NM    | 87114 | 47341     | OOBSAY IT WITH CAKE     | CAKE DECORATING     |
# |  00BSAY IT WITH CAKE     | 50534        | 10200 GOLF COURSE RD NW STE B | ALBUQUERQUE | NM    | 87114 | 47341     | OOBSAY IT WITH CAKE     | CAKE DECORATING     |
# |  2000 VIETNAM RESTAURANT | 31468        | 601 SAN MATEO BLVD SE         | ALBUQUERQUE | NM    | 87108 | 29294     | 2000 VIETMAN RESTAURANT | RESTAURANT          |
# |  2000 VIETNAM RESTAURANT | 31468        | 601 SAN MATEO BLVD SE         | ALBUQUERQUE | NM    | 87108 | 29294     | 2000 VIETMAN RESTAURANT | RESTAURANT          |
# |  2000 VIETNAM RESTAURANT | 31468        | 601 SAN MATEO BLVD SE         | ALBUQUERQUE | NM    | 87108 | 29294     | 2000 VIETMAN RESTAURANT | RESTAURANT          |
# |  328 CHINESE CUISINE     | 72789        | 5617 MENAUL BLVD NE STE A     | ALBUQUERQUE | NM    | 87110 | 66644     | 328 CHINESE CUISINE     |                     |
# |--------------------------+--------------+-------------------------------+-------------+-------+-------+-----------+-------------------------+---------------------|

# %%
# !csvcut -c10-18 abq.csv | head -10 | csvlook
# Out:
# |----------------+-------------+-------------+------------------+------------+------------------+------------------------------+---------------------+------------------|
# |  STREET_NUMBER | STREET_NAME | STREET_TYPE | POST_DIRECTIONAL | PHONE      | PROGRAM_CATEGORY | PROGRAM_CATEGORY_DESCRIPTION | INSPECTION_DATE     | INSPECTION_TYPE  |
# |----------------+-------------+-------------+------------------+------------+------------------+------------------------------+---------------------+------------------|
# |  10200         | GOLF COURSE | RD          | NW               | 5058339563 | 0405             | Food Processor               | 2009-10-21 00:00:00 |                  |
# |  10200         | GOLF COURSE | RD          | NW               | 5058339563 | 0405             | Food Processor               | 2009-10-21 00:00:00 |                  |
# |  10200         | GOLF COURSE | RD          | NW               | 5058339563 | 0405             | Food Processor               | 2009-10-21 00:00:00 |                  |
# |  10200         | GOLF COURSE | RD          | NW               | 5058339563 | 0405             | Food Processor               | 2010-04-14 00:00:00 |                  |
# |  10200         | GOLF COURSE | RD          | NW               | 5058339563 | 0405             | Food Processor               | 2010-04-14 00:00:00 |                  |
# |  601           | SAN MATEO   | BLVD        | SE               | 5052320900 | 0406             | Food Service Establishment   | 2010-03-23 00:00:00 |                  |
# |  601           | SAN MATEO   | BLVD        | SE               | 5052320900 | 0406             | Food Service Establishment   | 2010-03-23 00:00:00 |                  |
# |  601           | SAN MATEO   | BLVD        | SE               | 5052320900 | 0406             | Food Service Establishment   | 2010-03-23 00:00:00 |                  |
# |  5617          | MENAUL      | BLVD        | NE               | 5058814468 | 0406             | Food Service Establishment   | 2009-12-15 00:00:00 |                  |
# |----------------+-------------+-------------+------------------+------------+------------------+------------------------------+---------------------+------------------|

# %%
# !csvcut -c19-27 abq.csv | head -10 | csvlook
# Out:
# |--------------------------+------------+-------------+-------------+-------------+----------------+----------------+----------------------------------+------------------|
# |  INSPECTION_DESC         | SERIAL_NUM | ACTION_CODE | ACTION_DESC | RESULT_CODE | RESULT_DESC    | VIOLATION_CODE | VIOLATION_DESC                   | INSPECTION_MEMO  |
# |--------------------------+------------+-------------+-------------+-------------+----------------+----------------+----------------------------------+------------------|
# |  EMERGENCY RESPONSE      | DA8009125  | 00          | NON-GRADED  | 00          | NOT APPLICABLE |     68         | Delivered Informational Brochure |                  |
# |  ROUTINE FOOD INSPECTION | DA8009123  | 11          | APPROVED    | 03          | IN COMPLIANCE  |     00         | No Violations Found              |                  |
# |  ROUTINE FOOD INSPECTION | DA8009123  | 11          | APPROVED    | 03          | IN COMPLIANCE  |     55         | Additional Comments              |                  |
# |  ROUTINE FOOD INSPECTION | DA8010205  | 11          | APPROVED    | 03          | IN COMPLIANCE  |     00         | No Violations Found              |                  |
# |  ROUTINE FOOD INSPECTION | DA8010205  | 11          | APPROVED    | 03          | IN COMPLIANCE  |     55         | Additional Comments              |                  |
# |  ROUTINE FOOD INSPECTION | DA8509472  | 11          | APPROVED    | 03          | IN COMPLIANCE  |     34         | Food contact surfaces            |                  |
# |  ROUTINE FOOD INSPECTION | DA8509472  | 11          | APPROVED    | 03          | IN COMPLIANCE  |     35         | Non-Food contact surfaces        |                  |
# |  ROUTINE FOOD INSPECTION | DA8509472  | 11          | APPROVED    | 03          | IN COMPLIANCE  |     55         | Additional Comments              |                  |
# |  EMERGENCY RESPONSE      | DA7757250  | 00          | NON-GRADED  | 00          | NOT APPLICABLE |     68         | Delivered Informational Brochure |                  |
# |--------------------------+------------+-------------+-------------+-------------+----------------+----------------+----------------------------------+------------------|

# %% [markdown]
# Step 4: View summary statistics for each field

# %%
# !csvcut abq.csv | csvstat
# Out:
#   1. FACILITY_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 2615
# 	5 most frequent values:
# 		SMITHS FOOD AND DRUG CENTERS INC:	154
# 		ISOTOPES PARK - OVATIONS:	93
# 		PER EHSII CECELIA GARCIA OOB LA REYNA DEL SUR:	85
# 		ECHO INC:	68
# 		ISLETA AMPHITHEATER:	68
# 	Max length: 77
#   2. FACILITY_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 13
# 	Max: 101482
# 	Sum: 820405773
# 	Mean: 46730.79135338346
# 	Median: 50866.0
# 	Standard Deviation: 32659.794578837962
# 	Unique values: 2835
# 	5 most frequent values:
# 		46323:	93
# 		65863:	85
# 		80949:	68
# 		32817:	68
# 		91825:	66
#   3. SITE_ADDRESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 2456
# 	5 most frequent values:
# 		1601 AVENIDA CESAR CHAVEZ SE:	94
# 		644 OLD COORS BLVD SW:	85
# 		8601 CENTRAL AV NE:	77
# 		2200 SUNPORT BLVD SE:	75
# 		5210 CENTRAL AV SE:	73
# 	Max length: 35
#   4. CITY
# 	<class 'str'>
# 	Nulls: False
# 	Values: ALBUQUERQUE
#   5. STATE
# 	<class 'str'>
# 	Nulls: False
# 	Values: NM, 87
#   6. ZIP
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 48
# 	5 most frequent values:
# 		87110:	1996
# 		87108:	1976
# 		87102:	1601
# 		87106:	1568
# 		87109:	1552
# 	Max length: 10
#   7. OWNER_KEY
# 	<class 'int'>
# 	Nulls: False
# 	Min: 11
# 	Max: 87302
# 	Sum: 644760848
# 	Mean: 36725.953975848715
# 	Median: 33747.0
# 	Standard Deviation: 29428.207216739836
# 	Unique values: 1892
# 	5 most frequent values:
# 		1838:	792
# 		3537:	321
# 		1272:	228
# 		36280:	156
# 		80274:	155
#   8. OWNER_NAME
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 1852
# 	5 most frequent values:
# 		APS:	792
# 		SMITHS FOOD AND DRUG CENTERS INC:	321
# 		CIRCLE K STORES INC:	277
# 		ALBERTSONS:	228
# 		WAL MART STORES EAST  LP:	156
# 	Max length: 82
#   9. NATURE_OF_BUSINESS
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 594
# 	5 most frequent values:
# 		RESTAURANT:	4994
# 		FOOD SERVICE:	691
# 		GROCERY:	618
# 		BAR/RESTAURANT:	508
# 		APS SCHOOL FOOD SERVICE:	470
# 	Max length: 25
#  10. STREET_NUMBER
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 1349
# 	5 most frequent values:
# 		6600:	216
# 		10000:	152
# 		300:	143
# 		2200:	127
# 		8100:	125
# 	Max length: 7
#  11. STREET_NAME
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 404
# 	5 most frequent values:
# 		CENTRAL:	1898
# 		MENAUL:	928
# 		COORS:	918
# 		MONTGOMERY:	727
# 		SAN MATEO:	707
# 	Max length: 24
#  12. STREET_TYPE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 13
# 	5 most frequent values:
# 		BLVD:	7636
# 		AV:	3005
# 		ST:	2065
# 		RD:	1900
# 		DR:	995
# 	Max length: 4
#  13. POST_DIRECTIONAL
# 	<class 'str'>
# 	Nulls: True
# 	Values: SE, N, NE, NW, SW
#  14. PHONE
# 	<class 'int'>
# 	Nulls: True
# 	Min: 2471094
# 	Max: 505345566137310
# 	Sum: 2608539289633190
# 	Mean: 161719732773.29138
# 	Median: 5053454060.0
# 	Standard Deviation: 8895791545525.992
# 	Unique values: 2279
# 	5 most frequent values:
# 		9153321301:	101
# 		3037929467:	100
# 		5052224033:	94
# 		3109680646:	85
# 		5052426777:	68
#  15. PROGRAM_CATEGORY
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 25
# 	5 most frequent values:
# 		0406:	7969
# 		0601:	1159
# 		0607:	894
# 		0606:	865
# 		0501:	832
# 	Max length: 4
#  16. PROGRAM_CATEGORY_DESCRIPTION
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 24
# 	5 most frequent values:
# 		Food Service Establishment:	7969
# 		Retail -Grocery:	1159
# 		Retail - Self Service & Prepackage Foods:	894
# 		Retail - Prepackage Only:	865
# 		Bar:	832
# 	Max length: 40
#  17. INSPECTION_DATE
# 	<class 'datetime.date'>
# 	Nulls: False
# 	Min: 2009-07-01
# 	Max: 2010-06-30
# 	Unique values: 258
# 	5 most frequent values:
# 		2009-12-16:	184
# 		2009-09-10:	159
# 		2009-09-25:	148
# 		2009-11-04:	133
# 		2009-10-01:	131
#  18. INSPECTION_TYPE
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#  19. INSPECTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 15
# 	5 most frequent values:
# 		ROUTINE FOOD INSPECTION:	12439
# 		EMERGENCY RESPONSE:	1987
# 		New Business Inspection:	1005
# 		PRE-OPENING FOOD INSPECTION:	743
# 		ADDITIONAL SERVICE PROVIDED:	439
# 	Max length: 32
#  20. SERIAL_NUM
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 9046
# 	5 most frequent values:
# 		DA0045676:	61
# 		DA0045731:	61
# 		DA0047290:	61
# 		DA0059230:	61
# 		DA0047720:	61
# 	Max length: 9
#  21. ACTION_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		11:	14080
# 		00:	2800
# 		09:	382
# 		06:	264
# 		10:	21
# 	Max length: 2
#  22. ACTION_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 8
# 	5 most frequent values:
# 		APPROVED:	14080
# 		NON-GRADED:	2800
# 		ANNUAL STICKER ISSUED:	382
# 		UNSATISFACTORY:	264
# 		ANNUAL STICKER NOT ISSUED:	21
# 	Max length: 34
#  23. RESULT_CODE
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		03:	14389
# 		00:	2416
# 		05:	214
# 		22:	142
# 		18:	104
# 	Max length: 2
#  24. RESULT_DESC
# 	<class 'str'>
# 	Nulls: False
# 	Unique values: 19
# 	5 most frequent values:
# 		IN COMPLIANCE:	14389
# 		NOT APPLICABLE:	2416
# 		DOWNGRADE:	214
# 		OUT OF BUSINESS:	142
# 		TRAINING RECEIVED:	104
# 	Max length: 37
#  25. VIOLATION_CODE
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 128
# 	5 most frequent values:
# 		55:	6348
# 		00:	3429
# 		68:	1658
# 		42:	487
# 		35:	441
# 	Max length: 10
#  26. VIOLATION_DESC
# 	<class 'str'>
# 	Nulls: True
# 	Unique values: 70
# 	5 most frequent values:
# 		Additional Comments:	6353
# 		No Violations Found:	3434
# 		Delivered Informational Brochure:	1657
# 		Plumbing: Improperly installed/maintained/supplied:	492
# 		Non-Food contact surfaces:	446
# 	Max length: 50
#  27. INSPECTION_MEMO
# 	<class 'NoneType'>
# 	Nulls: True
# 	Values:
#
# Row count: 17556

# %% [markdown]
# My observations after looking at above stats are described below:
#
# Null values: Null values exist in a handful of the fields including: site_address, nature_of_business, street_number, street_name, street_type, post_directional, phone, program_category_description, inspection_type, violation_code, violation_desc, and inspection_memo.
#
# Potential questions/quirks:
# 1) Why is the street address unavailable for certain restaurants eventhough city, state, and zip information is available?
# 2) Why is nature_of_business null for some of these restaurants?
# 3) Why are there null values in program_category_description but no null values in program_category? I would expect that every program_category value would have a value populated in program_category_description.
# 4) Why are there no values in the inspection_type and inspection_memo fields?
# 5) Why is there not a 1:1 relationship between facility_name and facility_key?

# %% [markdown]
# ## Problem 2 - define a database model and load the data (35 points)
#
# Based on what you found above, create and connect to a new database, define a database table in it, and load this dataset into it.  You may use either of the methods for this step you have seen in earlier class notebooks.  You may choose to eliminate variables/columns if they are not relevant or interesting to you - explain your reasoning if you do.  Either way, you should load a majority of the columns present in the source dataset into the database and all of its rows.
#
# Once your data has loaded successfully, run a `COUNT(*)` query to verify that all the data has loaded correctly.
#
# Insert a combination of code and text/markdown cells here to connect to your database, define your table, load its data, and verify the loaded records.

# %% [markdown]
# Step 1: Set up and configure database

# %%
# %load_ext sql
# Out:
# /opt/conda/lib/python3.5/site-packages/IPython/config.py:13: ShimWarning: The `IPython.config` package has been deprecated. You should import from traitlets.config instead.
#   "You should import from traitlets.config instead.", ShimWarning)
# /opt/conda/lib/python3.5/site-packages/IPython/utils/traitlets.py:5: UserWarning: IPython.utils.traitlets has moved to a top-level traitlets package.
#   warn("IPython.utils.traitlets has moved to a top-level traitlets package.")

# %%
# !echo 'redspot' | sudo -S service postgresql restart
# Out:
# [sudo] password for jovyan: Restarting PostgreSQL 9.5 database server: main.

# %%
# !createdb -U dbuser week7

# %%
# %sql postgresql://dbuser@localhost:5432/week7
# Out:
# 'Connected: dbuser@week7'

# %% [markdown]
# Step 2: Create database. Field lengths derived from metadata document.

# %%
# %%sql
# DROP TABLE IF EXISTS abq;
# CREATE TABLE abq (
#     facility_name VARCHAR(202),
#     facility_key VARCHAR(20),
#     site_address VARCHAR(102),
#     city VARCHAR(52),
#     state VARCHAR(6),
#     zip VARCHAR(22),
#     owner_key VARCHAR(26),
#     owner_name VARCHAR(202),
#     nature_of_business VARCHAR(25),
#     street_number VARCHAR(16),
#     street_name VARCHAR(52),
#     street_type VARCHAR(10),
#     post_directional VARCHAR(6),
#     phone VARCHAR(42),
#     program_category VARCHAR(10),
#     program_category_description VARCHAR(92),
#     inspection_date TIMESTAMP,
#     inspection_type VARCHAR(4),
#     inspection_desc VARCHAR(102),
#     serial_num VARCHAR(20),
#     action_code VARCHAR(6),
#     action_desc VARCHAR(102),
#     result_code VARCHAR(6),
#     result_desc VARCHAR(102),
#     violation_code VARCHAR(14),
#     violation_desc VARCHAR(202),
#     inspection_memo VARCHAR(502)
# )
# Out:
# Done.
# Done.
# []

# %% [markdown]
# Step 3: Copy data from csv file to newly created database and confirm all rows (17,556) were successfully loaded.

# %%
# !pwd
# Out:
# /home/jovyan/work

# %%
# %%sql
# COPY abq FROM '/home/jovyan/work/abq.csv'
# CSV
# HEADER
# QUOTE '"'
# DELIMITER ',';
# Out:
# 17556 rows affected.
# []

# %%
# %%sql
# SELECT COUNT(*) FROM abq;
# Out:
# 1 rows affected.
# [(17556,)]

# %% [markdown]
# ## Problem 3 - explore your data (30 points)
#
# Now that the data is loaded, ask some questions of it!  Identify key variables of interest and note their ranges along with other useful descriptive statistics.  Choose and define a few lines of inquiry, execute queries for each, and describe what you find in your result sets.  Use any query techniques we've seen in class, including aggregate functions, transformations, subqueries, or others as appropriate.
#
# If you find interesting patterns, adding plots to your exploration would be useful.
#
# Insert a combination of code and text/markdown cells here to explore your data.

# %% [markdown]
# **Step 0: Sample data**

# %%
# %%sql
# select *
# from abq
# limit 3;
# Out:
# 3 rows affected.
# [('00BSAY IT WITH CAKE', '50534', '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', '47341', 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2009, 10, 21, 0, 0), None, 'EMERGENCY RESPONSE', 'DA8009125', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('00BSAY IT WITH CAKE', '50534', '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', '47341', 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2009, 10, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8009123', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    00    ', 'No Violations Found', None),
#  ('00BSAY IT WITH CAKE', '50534', '10200 GOLF COURSE RD NW STE B', 'ALBUQUERQUE', 'NM', '87114', '47341', 'OOBSAY IT WITH CAKE', 'CAKE DECORATING', '10200', 'GOLF COURSE', 'RD', 'NW', '5058339563', '0405', 'Food Processor', datetime.datetime(2009, 10, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8009123', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    55    ', 'Additional Comments', None)]

# %% [markdown]
# **Step 1: Descriptive statistics**

# %% [markdown]
# Program category description summary

# %%
# %%sql
# select program_category_description
#  , count(*) as vol
# from abq
# group by program_category_description
# order by 1;
# Out:
# 25 rows affected.
# [('Bakery', 343),
#  ('Bar', 832),
#  ('Childcare', 748),
#  ('Food Processor', 489),
#  ('Food Service Establishment', 7969),
#  ('Food/Drink Vending - Up to 15 Units', 6),
#  ('Frozen Food Truck', 90),
#  ('Institutional Kitchen', 357),
#  ('Limited Menu', 288),
#  ('Meat Market', 121),
#  ('Mobile Food Unit', 341),
#  ('Mobile Pre-Packaged', 515),
#  ('NOT FOR PROFIT KITCHEN PERMIT', 73),
#  ('Non School', 319),
#  ('Retail - Deli', 339),
#  ('Retail - Meat/Seafood', 294),
#  ('Retail - Prepackage Only', 865),
#  ('Retail - Self Service & Prepackage Foods', 894),
#  ('Retail - Specialty Food Permit', 113),
#  ('Retail -Grocery', 1159),
#  ('School', 832),
#  ('Seasonal Location -Food Service Permit', 67),
#  ('Seasonal Venue -Fixed Location', 203),
#  ('Warehouse', 203),
#  (None, 96)]

# %% [markdown]
# Inspection description summary

# %%
# %%sql
# select inspection_desc
#  , count(*) as vol
# from abq
# group by inspection_desc
# order by 1;
# Out:
# 15 rows affected.
# [('ADDITIONAL SERVICE PROVIDED', 439),
#  ('COMPLAINT FOOD INSPECTION', 1),
#  ('E-MAIL', 1),
#  ('EMERGENCY RESPONSE', 1987),
#  ('FIRE CALL', 5),
#  ('FOLLOW-UP DOCUMENTATION RECEIVED', 75),
#  ('FOOD FOLLOW-UP INSPECTION', 143),
#  ('IMMINENT HEALTH HAZARD', 36),
#  ('MANAGERIAL ASSISTANCE', 54),
#  ('MOBILE UNIT FOOD INSPECTION', 377),
#  ('New Business Inspection', 1005),
#  ('PHONE CALL', 247),
#  ('PLAN REVIEW INSPECTION', 4),
#  ('PRE-OPENING FOOD INSPECTION', 743),
#  ('ROUTINE FOOD INSPECTION', 12439)]

# %% [markdown]
# Result description summary

# %%
# %%sql
# select result_desc
#  , count(*) as vol
# from abq
# group by result_desc
# order by 1;
# Out:
# 19 rows affected.
# [('DOWNGRADE', 214),
#  ('EMBARGO', 3),
#  ('FACILITY CLOSED AT TIME OF INSPECTION', 19),
#  ('IMMEDIATE CLOSURE', 45),
#  ('IN COMPLIANCE', 14389),
#  ('NOT APPLICABLE', 2416),
#  ('NOT IN COMPLIANCE', 24),
#  ('NOTICE', 3),
#  ('OUT OF BUSINESS', 142),
#  ('PERMISSION TO OPERATE', 1),
#  ('PERMIT REINSTATEMENT', 11),
#  ('PERMIT SUSPENSION', 2),
#  ('PHONE CALL', 90),
#  ('PLAN REVIEW -APPROVED', 2),
#  ('RECALL VERIFICATION', 16),
#  ('TRAINING RECEIVED', 104),
#  ('UPGRADE', 69),
#  ('VOLUNTARY CLOSURE', 1),
#  ('WITNESS TO DESTRUCTION', 5)]

# %% [markdown]
# Violation description summary

# %%
# %%sql
# select violation_desc
#  , count(*) as vol
# from abq
# group by violation_desc
# order by 1;
# Out:
# 71 rows affected.
# [('Additional Comments', 6353),
#  ('Adulterated food', 28),
#  ('Barehand Contact with ready to eat food', 41),
#  ('Bent, swollen containers', 21),
#  ('Cold Holding', 201),
#  ('Complaint Not Substantiated', 12),
#  ('Complaint Substantiated', 8),
#  ('Contaminated equipment', 20),
#  ('Cooking Temperatures', 6),
#  ('Cooling, Heating Procedures', 57),
#  ('Cross connection, back siphonage, backflow', 5),
#  ('Delivered Informational Brochure', 1657),
#  ('Downgrade Statement', 15),
#  ('Enough facilities to maintain product temps', 16),
#  ('Evidence of insects', 42),
#  ('Evidence of rodents', 23),
#  ('Floors, Walls, Ceilings', 406),
#  ('Food Cross Contamination', 33),
#  ('Food contact surfaces', 251),
#  ('Food dispensing utensils improperly stored', 97),
#  ('Food improperly labeled', 134),
#  ('Food unprotected', 425),
#  ('Garbage area improperly maintained or constructed', 24),
#  ('Handwash Facilities - Inaccessible, unavailable', 89),
#  ('Handwash Facilities - Inadequate', 18),
#  ('Hot Holding', 175),
#  ('IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD', 9),
#  ('INFESTATION', 5),
#  ('Improper handwashing', 40),
#  ('Improper sanitizing', 434),
#  ('Improper storage/handling of clean equipment/utens', 93),
#  ('Improper use of wiping cloths', 124),
#  ('Inadequate water source, Hot or cold', 42),
#  ('Insect, rodents, animals - Other', 9),
#  ('LACK OF REFIGERATIONS', 2),
#  ('LACK OF REFRIGERATION', 3),
#  ('Maintenance & Operation', 1),
#  ('NO HOT WATER', 5),
#  ('No Violations Found', 3434),
#  ('No violations found at time of inspection.', 1),
#  ('Non-Food contact surfaces', 446),
#  ('Notice Statement', 1),
#  ('OBSERVATIONS', 11),
#  ('OPERATING WITHOUT A VALID PERMIT', 61),
#  ('OTHER', 5),
#  ('OTHER - MISCELLEANOUS', 1),
#  ('Other Operations - Lighting', 142),
#  ('Other Operations - Linen', 12),
#  ('Other Operations - Living/Sleeping/Laundry', 10),
#  ('Other Operations - Personal Items', 48),
#  ('Other Operations - Premises', 96),
#  ('Other Operations - Ventilation', 25),
#  ('Personnel w/infection restricted/excluded', 6),
#  ('Plumbing: Improperly installed/maintained/supplied', 492),
#  ('Poor Hygienic Practices- No hair restraints', 16),
#  ('Poor Hygienic Practices- Soiled Clothing', 7),
#  ('Potentially hazardous food improperly thawed', 63),
#  ('Reheating Temp', 45),
#  ('SEWAGE IN FACILITY', 5),
#  ('Smoking, Eating, Drinking', 114),
#  ('Thermometers not provided, not accurate/consp', 183),
#  ('Toilet room fixtures', 49),
#  ('Toxic Items- Improper Labels', 44),
#  ('Toxic Items- Improper Storage', 39),
#  ('Toxic Items- Improper Usage', 20),
#  ('Unapproved Source', 14),
#  ('Unapproved container', 22),
#  ('Unapproved sewage and wastewater disposal', 18),
#  ('Warewashing Thermometers/Test Kits not provided', 113),
#  ('Warewashing facilities', 80),
#  (None, 1009)]

# %% [markdown]
# **Step 2: Investigative Queries**

# %% [markdown]
# My queries below will focus on trends and insights involving restaurants that are found to have health code violations.

# %% [markdown]
# Question 1: Which restaurants had the largest number of inspections that resulted in a potentially negative outcome? For these purpoes, I've defined a potentially negative outcome as a violation description not equal to the ones defiend below.

# %%
# %%sql
# select facility_name
#  , count(*) as vol
# from abq
# where violation_desc not in ('Additional Comments', 'Complaint Not Substantiated', 'No Violations Found', 'No violations found at time of inspection.', 'None')
# group by facility_name
# order by 2 desc
# limit 10;
# Out:
# 10 rows affected.
# [('CIRCLE K 8936', 62),
#  ('DIONS PIZZA', 61),
#  ('OOB MOM THAI FOOD', 59),
#  ('CIRCLE K 8940', 59),
#  ('ECHO INC', 59),
#  ('SMITHS FOOD AND DRUG CENTERS INC', 48),
#  ('99 BANH SUPERMARKET', 41),
#  ('MCDONALDS', 33),
#  ('TALIN MARKET WORLD FOOD FARE', 32),
#  ('EL MEZQUITE MARKET LLC', 27)]

# %% [markdown]
# Question 2: What do the inspection details for DIONS PIZZA look like?. Majority of items noted are from Pre-opening food inspection.

# %%
# %%sql
# select *
# from abq
# where violation_desc not in ('Additional Comments', 'Complaint Not Substantiated', 'No Violations Found', 'No violations found at time of inspection.', 'None')
#  and facility_name = 'DIONS PIZZA'
# order by inspection_date;
# Out:
# 61 rows affected.
# [('DIONS PIZZA', '723', '4200 MONTANO RD NW', 'ALBUQUERQUE', 'NM', '87120', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '4200', 'MONTANO', 'RD', 'NW', '5058981161', '0406', 'Food Service Establishment', datetime.datetime(2009, 11, 6, 0, 0), None, 'EMERGENCY RESPONSE', 'DA8009281', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('DIONS PIZZA', '723', '4200 MONTANO RD NW', 'ALBUQUERQUE', 'NM', '87120', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '4200', 'MONTANO', 'RD', 'NW', '5058981161', '0406', 'Food Service Establishment', datetime.datetime(2009, 11, 6, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA8009279', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    38    ', 'Food unprotected', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  01', 'Cold Holding', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  02', 'Hot Holding', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  03', 'Reheating Temp', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  04', 'Cooking Temperatures', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  05', 'Cooling, Heating Procedures', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  06', 'Personnel w/infection restricted/excluded', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  07', 'Improper handwashing', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  08', 'Barehand Contact with ready to eat food', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  09', 'Smoking, Eating, Drinking', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  10', 'Food Cross Contamination', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  11', 'Contaminated equipment', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  12', 'Enough facilities to maintain product temps', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  13', 'Adulterated food', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  14', 'Unapproved Source', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  15', 'Bent, swollen containers', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  16', 'Inadequate water source, Hot or cold', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  17', 'Unapproved sewage and wastewater disposal', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  18', 'Cross connection, back siphonage, backflow', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  19', 'Handwash Facilities - Inaccessible, unavailable', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  20', 'Handwash Facilities - Inadequate', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  21', 'Improper sanitizing', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  22', 'Improper use of wiping cloths', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  23', 'Toxic Items- Improper Usage', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  24', 'Toxic Items- Improper Labels', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  25', 'Toxic Items- Improper Storage', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  26', 'Evidence of insects', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  27', 'Evidence of rodents', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  28', 'Insect, rodents, animals - Other', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  29', 'Poor Hygienic Practices- Soiled Clothing', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  30', 'Poor Hygienic Practices- No hair restraints', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  31', 'Warewashing Thermometers/Test Kits not provided', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  32', 'Improper storage/handling of clean equipment/utens', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  33', 'Warewashing facilities', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  34', 'Food contact surfaces', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  35', 'Non-Food contact surfaces', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  36', 'Thermometers not provided, not accurate/consp', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  37', 'Potentially hazardous food improperly thawed', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  38', 'Food unprotected', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  39', 'Food dispensing utensils improperly stored', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  40', 'Food improperly labeled', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  41', 'Unapproved container', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  42', 'Plumbing: Improperly installed/maintained/supplied', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  43', 'Toilet room fixtures', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  44', 'Garbage area improperly maintained or constructed', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  45', 'Floors, Walls, Ceilings', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  46', 'Other Operations - Lighting', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  47', 'Other Operations - Ventilation', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  48', 'Other Operations - Personal Items', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  49', 'Other Operations - Linen', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  50', 'Other Operations - Living/Sleeping/Laundry', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  51', 'Other Operations - Premises', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  58', 'OPERATING WITHOUT A VALID PERMIT', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  59', 'OBSERVATIONS', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  60', 'Complaint Substantiated', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  69', 'NO HOT WATER', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  70', 'LACK OF REFRIGERATION', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  71', 'SEWAGE IN FACILITY', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  72', 'INFESTATION', None),
#  ('DIONS PIZZA', '90924', '6308 4TH ST NW ', 'ALBUQUERQUE', 'NM', '87107', '610', 'PETER DEFRIES CORP', 'RESTAURANT', '6308', '4TH', 'ST', 'NW', '5053454900', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 16, 0, 0), None, 'PRE-OPENING FOOD INSPECTION', 'DA0059230', '11', 'APPROVED', '03', 'IN COMPLIANCE', '04  73', 'OTHER', None)]

# %% [markdown]
# Question 3: Which restaurants had the largest number of emergency or health hazard inspections?

# %%
# %%sql
# select facility_name
#  , count(*) as vol
# from abq
# where inspection_desc in ('EMERGENCY RESPONSE', 'IMMINENT HEALTH HAZARD')
# group by facility_name
# order by 2 desc
# limit 10;
# Out:
# 10 rows affected.
# [('SMITHS FOOD AND DRUG CENTERS INC', 15),
#  ('OOB MARKET FRESH CAFE', 10),
#  ('SUBWAY', 10),
#  ('VILLA PIZZA INC', 9),
#  ('GRAHAM CENTRAL STATION', 7),
#  ('MCDONALDS', 7),
#  ('OOB ROSYS', 7),
#  ('WECKS', 6),
#  ('CHICHARRONERIA DON CHOCHE', 6),
#  ('99 BANH SUPERMARKET', 6)]

# %% [markdown]
# Question 4: What do the emergency/hazard inspections look like for OOB Market fresh Cafe? It appears that all of these violations were associated with the same inspection.

# %%
# %%sql
# select *
# from abq
# where inspection_desc in ('EMERGENCY RESPONSE', 'IMMINENT HEALTH HAZARD')
#  and facility_name = 'OOB MARKET FRESH CAFE'
# order by inspection_date desc;
# Out:
# 10 rows affected.
# [('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    07    ', 'Improper handwashing', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    16    ', 'Inadequate water source, Hot or cold', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    19    ', 'Handwash Facilities - Inaccessible, unavailable', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    30    ', 'Poor Hygienic Practices- No hair restraints', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    36    ', 'Thermometers not provided, not accurate/consp', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    40    ', 'Food improperly labeled', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    45    ', 'Floors, Walls, Ceilings', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    49    ', 'Other Operations - Linen', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    52    ', 'IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD', None),
#  ('OOB MARKET FRESH CAFE', '85872', '800 LOUISIANA BLVD NE ', 'ALBUQUERQUE', 'NM', '87108', '77288', 'ZUBAIR REZA', 'COFFEE SHOP', '800', 'LOUISIANA', 'BLVD', 'NE', '5057152870', '0406', 'Food Service Establishment', datetime.datetime(2009, 7, 23, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7256041', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    55    ', 'Additional Comments', None)]

# %% [markdown]
# Question 5: Based on my examination above, I will adjust my query to identify the restaurants with the largest number of emergency/health hazard violations on distinct inspection dates.

# %%
# %%sql
# select b.facility_name
#  , count(b.*) as vol
# from
#     (select distinct facility_name, inspection_date
#     from abq
#     where inspection_desc in ('EMERGENCY RESPONSE', 'IMMINENT HEALTH HAZARD')) as b
# group by b.facility_name
# order by count(b.*) desc
# limit 10;
# Out:
# 10 rows affected.
# [('SUBWAY', 10),
#  ('SMITHS FOOD AND DRUG CENTERS INC', 7),
#  ('MCDONALDS', 7),
#  ('WECKS', 6),
#  ('LA PETITE ACADEMY', 6),
#  ('BLAKES LOTABURGER', 5),
#  ('DIONS', 5),
#  ('BURGER KING', 5),
#  ('KEVA JUICE SW LLC', 4),
#  ('GOLDEN PRIDE CHICKEN', 4)]

# %% [markdown]
# Question 6: What does the inspection detail for Subway look like? It appears these pertain to different locations.

# %%
# %%sql
# select *
# from abq
# where inspection_desc in ('EMERGENCY RESPONSE', 'IMMINENT HEALTH HAZARD')
#  and facility_name = 'SUBWAY'
# order by inspection_date desc;
# Out:
# 10 rows affected.
# [('SUBWAY', '79381', '5850 EUBANK BLVD NE ', 'ALBUQUERQUE', 'NM', '87111', '72487', 'DIACOUR LLC', 'RESTAURANT', '5850', 'EUBANK', 'BLVD', 'NE', '5052174112', '0406', 'Food Service Establishment', datetime.datetime(2010, 1, 6, 0, 0), None, 'EMERGENCY RESPONSE', 'DA7507370', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('SUBWAY', '83163', '8101 SAN PEDRO BLVD NE ', 'ALBUQUERQUE', 'NM', '87113', '68797', 'SUBWAY', 'SANDWICH SHOP', '8101', 'SAN PEDRO', 'BLVD', 'NE', '5057972298', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 22, 0, 0), None, 'EMERGENCY RESPONSE', 'DA7507245', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('SUBWAY', '88734', '8000 ACADEMY RD NE ', 'ALBUQUERQUE', 'NM', '87111', '80562', 'WIGH LLC', 'DELI', '8000', 'ACADEMY', 'RD', 'NE', '5058220074', '0406', 'Food Service Establishment', datetime.datetime(2009, 12, 15, 0, 0), None, 'EMERGENCY RESPONSE', 'DA7507180', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('SUBWAY', '28313', '3200 COORS BLVD NW ', 'ALBUQUERQUE', 'NM', '87120', '26318', 'JUAN C. LEVY', 'FOOD SERVICE', '3200', 'COORS', 'BLVD', 'NW', '5053520094', '0406', 'Food Service Establishment', datetime.datetime(2009, 11, 30, 0, 0), None, 'EMERGENCY RESPONSE', 'DA8009384', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('SUBWAY', '71764', '2225K WYOMING BLVD NE ', 'ALBUQUERQUE', 'NM', '87112', '64201', 'ARYAVART INC', 'SANDWICHES', '2225K', 'WYOMING', 'BLVD', 'NE', '5052751548', '0406', 'Food Service Establishment', datetime.datetime(2009, 11, 5, 0, 0), None, 'EMERGENCY RESPONSE', 'DA7756789', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('SUBWAY', '28312', '11111 MENAUL BLVD NE ', 'ALBUQUERQUE', 'NM', '87112', '26318', 'JUAN C. LEVY', 'FOOD SERVICE', '11111', 'MENAUL', 'BLVD', 'NE', '5052966783', '0406', 'Food Service Establishment', datetime.datetime(2009, 10, 30, 0, 0), None, 'EMERGENCY RESPONSE', 'DA7756731', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('SUBWAY', '71374', '523 LOMAS BLVD NW ', 'ALBUQUERQUE', 'NM', '87102', '46949', 'G & P INVESTMENTS INC', 'RESTUARANT', '523', 'LOMAS', 'BLVD', 'NW', '5052430249', '0406', 'Food Service Establishment', datetime.datetime(2009, 10, 26, 0, 0), None, 'EMERGENCY RESPONSE', 'DA8508436', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', None, None, None),
#  ('SUBWAY', '28313', '3200 COORS BLVD NW ', 'ALBUQUERQUE', 'NM', '87120', '26318', 'JUAN C. LEVY', 'FOOD SERVICE', '3200', 'COORS', 'BLVD', 'NW', '5053520094', '0406', 'Food Service Establishment', datetime.datetime(2009, 9, 25, 0, 0), None, 'EMERGENCY RESPONSE', 'DA8008894', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', '    68    ', 'Delivered Informational Brochure', None),
#  ('SUBWAY', '79380', '200 3RD ST NW STE 250', 'ALBUQUERQUE', 'NM', '87120', '72487', 'DIACOUR LLC', 'RESTAURANT', '200', '3RD', 'ST', 'NW', '5052449636', '0406', 'Food Service Establishment', datetime.datetime(2009, 9, 11, 0, 0), None, 'EMERGENCY RESPONSE', 'DA7005841', '00', 'NON-GRADED', '18', 'TRAINING RECEIVED', '    55    ', 'Additional Comments', None),
#  ('SUBWAY', '13328', '640 COORS BLVD NW ', 'ALBUQUERQUE', 'NM', '87105', '11977', 'BUCKMAR CORP INC', 'RESTAURANT', '640', 'COORS', 'BLVD', 'NW', '5058311588', '0406', 'Food Service Establishment', datetime.datetime(2009, 8, 12, 0, 0), None, 'EMERGENCY RESPONSE', 'DA0040973', '00', 'NON-GRADED', '00', 'NOT APPLICABLE', None, None, None)]

# %% [markdown]
# Question 7: Based on my examination above, I will adjust my query to identify the restaurants with the largest number of emergency/health hazard violations on distinct inspection dates for a distinct restaurant key.

# %%
# %%sql
# select b.facility_name
#  , b.facility_key
#  , count(b.*) as vol
# from
#     (select distinct facility_name, facility_key, inspection_date
#     from abq
#     where inspection_desc in ('EMERGENCY RESPONSE', 'IMMINENT HEALTH HAZARD')) as b
# group by b.facility_name
#  , b.facility_key
# order by count(b.*) desc
# limit 10;
# Out:
# 10 rows affected.
# [('GLORIAS NM BURRITOS AND MORE', '87553', 2),
#  ('OOB PER WRITTEN REQUEST K MART', '2608', 2),
#  ('CIBOLA -DECA SNACK BAR', '71571', 2),
#  ('PER EHSII ROSANNA TRUJILLO FA OOB 02/20/14 VALERO', '12288', 2),
#  ('KEVA JUICE SW LLC', '73182', 2),
#  ('OOB CHURCHILL CHEVRON REDIMART', '16260', 2),
#  ('HECTORS BAKERY', '31322', 2),
#  ('TARGET STORE 356', '8881', 2),
#  ('LOWELL CHILD DEVELOPMENT CENTER', '81272', 2),
#  ('CIBOLA HIGH SCHOOL', '2140', 2)]

# %% [markdown]
# Based on above, there are not too many repeat offenders, as no restaurant had more than 2 distinct emergency/health harzard inspections. Below is the same query with my original definition of a potentially negative inspection from Question 1.

# %%
# %%sql
# select b.facility_name
#  , b.facility_key
#  , count(b.*) as vol
# from
#     (select distinct facility_name, facility_key, inspection_date
#     from abq
#     where violation_desc not in ('Additional Comments', 'Complaint Not Substantiated', 'No Violations Found', 'No violations found at time of inspection.', 'None')) as b
# group by b.facility_name
#  , b.facility_key
# order by count(b.*) desc
# limit 10;
# Out:
# 10 rows affected.
# [('99 BANH SUPERMARKET', '18468', 5),
#  ('EL MEZQUITE MARKET LLC', '60817', 4),
#  ('OOB POP N TACO DRIVE UP INC.', '48566', 4),
#  ('OOB GARDUNOS CHILE PACKING CO', '5871', 4),
#  ('CHEVRON', '87139', 4),
#  ('LA MONTANITA NATL. FOOD COOP.', '4068', 3),
#  ('WALGREENS 03997', '1991', 3),
#  ('OOB BLACK MESA COFFEE CO', '20973', 3),
#  ('OOB CAPTAIN DS SEAFOOD', '6502', 3),
#  ('KEVA JUICE SW LLC', '73182', 3)]

# %% [markdown]
# Finally, the negative inspection detail for 99 Banh Supermarket which based on my analysis is not a place where I would shop!

# %%
# %%sql
# select *
# from abq
# where facility_key = '18468'
# and violation_desc not in ('Additional Comments', 'Complaint Not Substantiated', 'No Violations Found', 'No violations found at time of inspection.', 'None')
# order by inspection_date;
# Out:
# 41 rows affected.
# [('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256034', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    38    ', 'Food unprotected', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256034', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    40    ', 'Food improperly labeled', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256035', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    34    ', 'Food contact surfaces', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256035', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    32    ', 'Improper storage/handling of clean equipment/utens', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256035', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    02    ', 'Hot Holding', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256035', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    45    ', 'Floors, Walls, Ceilings', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256035', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    12    ', 'Enough facilities to maintain product temps', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256035', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    42    ', 'Plumbing: Improperly installed/maintained/supplied', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2009, 7, 21, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256035', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    35    ', 'Non-Food contact surfaces', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 8, 17, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256128', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    38    ', 'Food unprotected', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 8, 17, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256128', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    40    ', 'Food improperly labeled', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 8, 17, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256128', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    51    ', 'Other Operations - Premises', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 8, 17, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256128', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    01    ', 'Cold Holding', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 8, 17, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256128', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    35    ', 'Non-Food contact surfaces', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2009, 8, 17, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7256128', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    36    ', 'Thermometers not provided, not accurate/consp', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257070', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    13    ', 'Adulterated food', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257070', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    01    ', 'Cold Holding', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    02    ', 'Hot Holding', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257070', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    38    ', 'Food unprotected', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257070', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    40    ', 'Food improperly labeled', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257070', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    42    ', 'Plumbing: Improperly installed/maintained/supplied', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257070', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    52    ', 'IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    01    ', 'Cold Holding', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    21    ', 'Improper sanitizing', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    32    ', 'Improper storage/handling of clean equipment/utens', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    34    ', 'Food contact surfaces', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    42    ', 'Plumbing: Improperly installed/maintained/supplied', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    45    ', 'Floors, Walls, Ceilings', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 1, 29, 0, 0), None, 'ROUTINE FOOD INSPECTION', 'DA7257071', '11', 'APPROVED', '03', 'IN COMPLIANCE', '    52    ', 'IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 2, 11, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7257122', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    40    ', 'Food improperly labeled', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 2, 11, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7257123', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    52    ', 'IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 2, 11, 0, 0), None, 'IMMINENT HEALTH HAZARD', 'DA7257122', '06', 'UNSATISFACTORY', '14', 'IMMEDIATE CLOSURE', '    52    ', 'IMMEDIATE CLOSURE - IMMINENT HEALTH HAZARD', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257127', '11', 'APPROVED', '06', 'UPGRADE', '    35    ', 'Non-Food contact surfaces', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257127', '11', 'APPROVED', '06', 'UPGRADE', '    41    ', 'Unapproved container', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257126', '11', 'APPROVED', '06', 'UPGRADE', '    46    ', 'Other Operations - Lighting', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257126', '11', 'APPROVED', '06', 'UPGRADE', '    42    ', 'Plumbing: Improperly installed/maintained/supplied', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0601', 'Retail -Grocery', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257126', '11', 'APPROVED', '06', 'UPGRADE', '    40    ', 'Food improperly labeled', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257127', '11', 'APPROVED', '06', 'UPGRADE', '    32    ', 'Improper storage/handling of clean equipment/utens', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257127', '11', 'APPROVED', '06', 'UPGRADE', '    21    ', 'Improper sanitizing', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257127', '11', 'APPROVED', '06', 'UPGRADE', '    33    ', 'Warewashing facilities', None),
#  ('99 BANH SUPERMARKET', '18468', '5315 GIBSON BLVD SE ', 'ALBUQUERQUE', 'NM', '87108', '16883', 'GOLDEN CITIES INC', 'GROCERY STORE', '5315', 'GIBSON', 'BLVD', 'SE', '5052682422', '0608', 'Retail - Deli', datetime.datetime(2010, 2, 12, 0, 0), None, 'FOOD FOLLOW-UP INSPECTION', 'DA7257127', '11', 'APPROVED', '06', 'UPGRADE', '    34    ', 'Food contact surfaces', None)]

# %% [markdown]
# ## Bonus (10 points)
#
# We have seen a few simple techniques for normalizing data in class.  Choose a column or set of columns that might be redundant and normalize them out to another table:
#
# * Identify the columns to normalize in the source data table
# * Create one or more new tables to hold the normalized records
# * Extract data into the new tables
# * Re-insert the new foreign key references from the new table into the source table

# %% [markdown]
# Did not have time to complete bonus portion of assignment.
